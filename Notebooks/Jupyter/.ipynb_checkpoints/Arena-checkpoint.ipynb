# %% [markdown]
# # First Notebook

# %% [markdown]
# ## Print List

# %%
l = [1,2,3]
for el in l:
    print(el)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ## HTTP request

# %%
import requests
res = requests.get("https://google.com")
print(res)
# Out:
# <Response [200]>

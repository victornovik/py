# %%
import pandas as pd
import numpy as np

# %%
users = {
    "ID": [1,2,3,4,5],
    "Username": ["Victor", "Alex", "Tanya", "Lev", "Timofey"],
    "Age": [18, 35, 25, 38, 45],
    "Date": pd.to_datetime(["2032-01-01", "2032-02-15","2032-04-25","2032-06-21","2032-09-15"]),
    "Posts": [150, 230, 80, 420, None],
    "Reputation": [500, 720, 200, 940, 500]
}
df = pd.DataFrame(users)
df
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 0   1   Victor   18 2032-01-01  150.0         500
# 1   2     Alex   35 2032-02-15  230.0         720
# 2   3    Tanya   25 2032-04-25   80.0         200
# 3   4      Lev   38 2032-06-21  420.0         940
# 4   5  Timofey   45 2032-09-15    NaN         500

# %% [markdown]
# ## Filtering

# %%
df[["Username", "Age"]]
# Out:
#   Username  Age
# 0   Victor   18
# 1     Alex   35
# 2    Tanya   25
# 3      Lev   38
# 4  Timofey   45

# %%
df.loc[3]
# Out:
# ID                              4
# Username                      Lev
# Age                            38
# Date          2032-06-21 00:00:00
# Posts                       420.0
# Reputation                    940
# Name: 3, dtype: object

# %%
df.loc[2:3]
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 2   3    Tanya   25 2032-04-25   80.0         200
# 3   4      Lev   38 2032-06-21  420.0         940

# %%
df.loc[2:3, ["Username", "Reputation"]]
# Out:
#   Username  Reputation
# 2    Tanya         200
# 3      Lev         940

# %%
df.iloc[2:4, 1:4]
# Out:
#   Username  Age       Date
# 2    Tanya   25 2032-04-25
# 3      Lev   38 2032-06-21

# %%
# Select all rows
df.iloc[:, 1:4]
# Out:
#   Username  Age       Date
# 0   Victor   18 2032-01-01
# 1     Alex   35 2032-02-15
# 2    Tanya   25 2032-04-25
# 3      Lev   38 2032-06-21
# 4  Timofey   45 2032-09-15

# %%
# All rows where Age >= 25
df[df["Age"] > 25]
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 1   2     Alex   35 2032-02-15  230.0         720
# 3   4      Lev   38 2032-06-21  420.0         940
# 4   5  Timofey   45 2032-09-15    NaN         500

# %%
df[(df["Age"] > 25) & (df["Posts"] > 300)]
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 3   4      Lev   38 2032-06-21  420.0         940

# %%
df["Reputation"].isin([200, 500])
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: Reputation, dtype: bool

# %%
df[df["Reputation"].isin([200, 500])]
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 0   1   Victor   18 2032-01-01  150.0         500
# 2   3    Tanya   25 2032-04-25   80.0         200
# 4   5  Timofey   45 2032-09-15    NaN         500

# %%
df[df["Posts"].isin(range(200, 500))]
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 1   2     Alex   35 2032-02-15  230.0         720
# 3   4      Lev   38 2032-06-21  420.0         940

# %%
date_range = pd.date_range(start="2032-03-01", end="2032-08-01")
date_range
# Out:
# DatetimeIndex(['2032-03-01', '2032-03-02', '2032-03-03', '2032-03-04',
#                '2032-03-05', '2032-03-06', '2032-03-07', '2032-03-08',
#                '2032-03-09', '2032-03-10',
#                ...
#                '2032-07-23', '2032-07-24', '2032-07-25', '2032-07-26',
#                '2032-07-27', '2032-07-28', '2032-07-29', '2032-07-30',
#                '2032-07-31', '2032-08-01'],
#               dtype='datetime64[ns]', length=154, freq='D')

# %%
date_range = pd.date_range(start="2032-03-01", end="2032-08-01")
df[df["Date"].isin(date_range)]
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 2   3    Tanya   25 2032-04-25   80.0         200
# 3   4      Lev   38 2032-06-21  420.0         940

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by="Age")
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 0   1   Victor   18 2032-01-01  150.0         500
# 2   3    Tanya   25 2032-04-25   80.0         200
# 1   2     Alex   35 2032-02-15  230.0         720
# 3   4      Lev   38 2032-06-21  420.0         940
# 4   5  Timofey   45 2032-09-15    NaN         500

# %%
df.sort_values(by="Date", ascending=False)
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 4   5  Timofey   45 2032-09-15    NaN         500
# 3   4      Lev   38 2032-06-21  420.0         940
# 2   3    Tanya   25 2032-04-25   80.0         200
# 1   2     Alex   35 2032-02-15  230.0         720
# 0   1   Victor   18 2032-01-01  150.0         500

# %%
# All values in the row have to have the same type for sorting by columns within row 2
df[["ID", "Posts", "Reputation"]].sort_values(by=2, axis=1, ascending=False)
# Out:
#    Reputation  Posts  ID
# 0         500  150.0   1
# 1         720  230.0   2
# 2         200   80.0   3
# 3         940  420.0   4
# 4         500    NaN   5

# %%
df?
# Out:
# Type:        DataFrame
# String form:
# ID Username  Age       Date  Posts  Reputation
#            0   1   Victor   18 2032-01-01  150.0         5 <...>   4      Lev   38 2032-06-21  420.0         940
#            4   5  Timofey   45 2032-09-15    NaN         500
# Length:      5
# File:        c:\python\python312\lib\site-packages\pandas\core\frame.py
# Docstring:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order. If a dict contains Series
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Frames

# %%
users = {
    "ID": [1,2,3,4,5],
    "Username": ["Victor", "Alex", "Tanya", "Lev", "Scowl"],
    "Age": [18, 35, 25, 38, 45],
    "Date": pd.to_datetime(["2032-01-01", "2032-02-15","2032-04-25","2032-06-21","2032-09-15"]),
    "Posts": [150, 230, 80, 420, 310],
    "Reputation": [500, 720, 200, 940, None]
}
df = pd.DataFrame(users)
df
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 0   1   Victor   18 2032-01-01    150       500.0
# 1   2     Alex   35 2032-02-15    230       720.0
# 2   3    Tanya   25 2032-04-25     80       200.0
# 3   4      Lev   38 2032-06-21    420       940.0
# 4   5    Scowl   45 2032-09-15    310         NaN

# %%
df.shape
# Out:
# (5, 6)

# %%
# Column labels
df.columns.tolist()
# Out:
# ['ID', 'Username', 'Age', 'Date', 'Posts', 'Reputation']

# %%
# Row labels
df.index.tolist()
# Out:
# [0, 1, 2, 3, 4]

# %%
df.values
# Out:
# array([[1, 'Victor', 18, Timestamp('2032-01-01 00:00:00'), 150, 500.0],
#        [2, 'Alex', 35, Timestamp('2032-02-15 00:00:00'), 230, 720.0],
#        [3, 'Tanya', 25, Timestamp('2032-04-25 00:00:00'), 80, 200.0],
#        [4, 'Lev', 38, Timestamp('2032-06-21 00:00:00'), 420, 940.0],
#        [5, 'Scowl', 45, Timestamp('2032-09-15 00:00:00'), 310, nan]],
#       dtype=object)

# %%
df.values[1,1]
# Out:
# 'Alex'

# %%
# First 3 rows
df.head(3)
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 0   1   Victor   18 2032-01-01    150       500.0
# 1   2     Alex   35 2032-02-15    230       720.0
# 2   3    Tanya   25 2032-04-25     80       200.0

# %%
# Last 2 rows
df.tail(2)
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 3   4      Lev   38 2032-06-21    420       940.0
# 4   5    Scowl   45 2032-09-15    310         NaN

# %%
df.describe().round(2)
# Out:
#          ID    Age                 Date  Posts  Reputation
# count  5.00   5.00                    5    5.0        4.00
# mean   3.00  32.20  2032-04-28 00:00:00  238.0      590.00
# min    1.00  18.00  2032-01-01 00:00:00   80.0      200.00
# 25%    2.00  25.00  2032-02-15 00:00:00  150.0      425.00
# 50%    3.00  35.00  2032-04-25 00:00:00  230.0      610.00
# 75%    4.00  38.00  2032-06-21 00:00:00  310.0      775.00
# max    5.00  45.00  2032-09-15 00:00:00  420.0      940.00
# std    1.58  10.71                  NaN  133.3      316.02

# %%
# D = EX² - E²X
age = df["Age"]
squared_avg = age.mean()**2
avg_of_squares = age.apply(lambda x: x**2).sum() / len(age)
var = avg_of_squares - squared_avg
std = var ** 0.5
std
# Out:
# 9.579144011862425

# %%
# D = E(X - EX)²
age = df["Age"]
avg = age.mean()
var = age.apply(lambda x: (x - avg)**2).sum() / len(age)
std = var ** 0.5
std
# Out:
# 9.579144011862438

# %%
df["Age"].std(ddof=0)
# Out:
# 9.579144011862438

# %%
df
# Out:
#    ID Username  Age       Date  Posts  Reputation
# 0   1   Victor   18 2032-01-01    150       500.0
# 1   2     Alex   35 2032-02-15    230       720.0
# 2   3    Tanya   25 2032-04-25     80       200.0
# 3   4      Lev   38 2032-06-21    420       940.0
# 4   5    Scowl   45 2032-09-15    310         NaN

# %%
# Create new dataframe with selected column types
df.select_dtypes(include="int")
# Out:
#    ID  Age  Posts
# 0   1   18    150
# 1   2   35    230
# 2   3   25     80
# 3   4   38    420
# 4   5   45    310

# %%
# Create new dataframe without selected column types
df.select_dtypes(exclude="int")
# Out:
#   Username       Date  Reputation
# 0   Victor 2032-01-01       500.0
# 1     Alex 2032-02-15       720.0
# 2    Tanya 2032-04-25       200.0
# 3      Lev 2032-06-21       940.0
# 4    Scowl 2032-09-15         NaN

# %%
df.isna()
# Out:
#       ID  Username    Age   Date  Posts  Reputation
# 0  False     False  False  False  False       False
# 1  False     False  False  False  False       False
# 2  False     False  False  False  False       False
# 3  False     False  False  False  False       False
# 4  False     False  False  False  False        True

# %%
df.isna().sum()
# Out:
# ID            0
# Username      0
# Age           0
# Date          0
# Posts         0
# Reputation    1
# dtype: int64

# %% [markdown]
# ## Series
